# %%
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %% [raw]
# with open('D:/data/Output.txt', 'w', encoding='utf-8') as file:
#     file.write(df)
# file.close()

# %%
with open('D:/data/Output.txt', 'w', encoding='utf-8') as file:
    file.write(pytesseract.image_to_string(Image.open('E:/DOC030524-03052024073937/Page0001.tif')))
file.close()

# %%
test_file = pytesseract.image_to_string(Image.open(r"E:/DOC030524a-03052024120400/Page0001.tif"))

with open('D:/data/Output2.txt', 'w', encoding='utf-8') as file:
    file.write(test_file)
    file.close()

# %%
test_file = pytesseract.image_to_string(Image.open(r"E:/DOC030524a-03052024120400/Page0001.tif"))

with open('D:/data/Output2.txt', 'w', encoding='utf-8') as file:
    file.write(test_file)
    file.close()

# %%
import re

with open("D:/data/Output2.txt", "r") as f:
    text=f.read()

adjacent_text = re.findall(r"(?<=Employee Name:)(.*?)(?=IRIS Personnel Number)", text)

for data in adjacent_text:
    print(data)
# Out:
#  Alexis Davis

# %%
sarah = pytesseract.image_to_string(Image.open(r"E:\DOC0305255-03052024145923\Page0001.tif"))

with open('D:/data/Sarah.txt', 'w', encoding='utf-8') as file:
    file.write(sarah), 
with open('D:/data/Sarah.txt', 'r') as file:
    text=file.read()
    encounter = 
        first_name = re.search(r"(?<=First Name: )(.*?)(?=DOB:)", text),
        last_name = re.search(r"(?<=Last Name: )(.*?)(?=Race:)", text)
print(encounter)
# Out:
#   Cell In[69], line 8
#     first_name = re.search(r"(?<=First Name: )(.*?)(?=DOB:)", text),
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import csv

sarah = pytesseract.image_to_string(Image.open(r"E:\DOC0305255-03052024145923\Page0001.tif"))

with open('D:/data/Sarah.txt', 'w', encoding='utf-8') as file:
    file.write(sarah), 
with open('D:/data/Sarah.txt', 'r') as file:
    text=file.read()
    first_name = re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text),
    last_name = re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text)
    
with open('D:/data/encounter.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['first name', 'last name'])
    writer.writerow([first_name, last_name])

# %%
import pandas as pd
import pytesseract
from PIL import Image
import os
import re
import csv
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

sarah = pytesseract.image_to_string(Image.open(r"E:\DOC0305255-03052024145923\Page0001.tif"))

with open('D:/data/Sarah.txt', 'w', encoding='utf-8') as file:
    file.write(sarah), 
with open('D:/data/Sarah.txt', 'r') as file:
    text=file.read()
    first_name = re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text)
    last_name = re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text)
    DOB = re.findall(r"(?<=DOB:)(.*?)(?=Gender:)", text)
    gender = re.findall(r"(?<=Gender:)(.*?)(?=\n)", text)
    race = re.findall(r"(?<=Race:)(.*?)(?=Provider Pat ID:)", text)
    pro_pat_id = re.findall(r"(?<=Provider Pat ID:)(.*?)(?=\n)", text)
    SSN = re.findall(r"(?<=\n)(.*?)(?=Ethnicity:)", text) or re.findall(r"?<=SSN:)(.*?)(?=Ethinicity:)", text)
    ethnicity = re.findall(r"(?<=Ethnicity:)(.*?)(?=\n)", text)
    call_end = re.findall(r"(?<=Call End Date/Time:)(.*?)(?=Disposition:)", text)
    disposition = re.findall(r"(?<=Disposition:)(.*?)(?=\n)", text)
    dispatch = re.findall(r"(?<=Dispatch Date/Time:)(.*?)(?=\n)", text)
    ass_date = re.findall(r"(?<=Assessment Date:)(.*?)(?=Arrival Time:)", text)
    arrival = re.findall(r"(?<=Arrival Time:)(.*?)(?=Consumer)", text)
    location = re.findall(r"(?<=Consumer Location at Assessment:)(.*?)(?=\n)", text)
    LE_transport = re.findall(r"(?<=Transported by Law Enforcement:)(.*?)(?=Crisis...)", text)
    televideo = re.findall(r"(?<=Crisis Assessment via Televideo:)(.*?)(?=\n)", text)
    payor_source_prime = re.findall(r"(?<=Payor Source, Primary:)(.*?)(?=Current...)", text)
    current_srvcs = re.findall(r"(?<=Current Services being Received:)(.*?)(?=\n)", text)
    payor_source_sec = re.findall(r"(?<=Payor Source, Secondary:)(.*?)(?=Declaration...)", text)
    mh_treat = re.findall(r"(?<=Declaration of MH Treatment:)(.*?)(?=\n)", text)
    hh_income = re.findall(r"(?<=Annual Gross HH Income:)(.*?)(?=Durable...)", text)
    MOT = re.findall(r"(?<=MOT Status:)(.*?)(?=\n)", text)
    ppl_hh = re.findall(r"(?<=No. of People in HH)(.*?)(?=Durable...)", text)
    poa = re.findall(r"(?<=Durable POA/Conservator/Guardian:)(.*?)(?=\n)", text)
    res_stat = re.findall(r"(?<=Residential Status:)(.*?)(?=Marital Status)", text)
    marital = re.findall(r"(?<=Marital Status:)(.*?)(?=\n)", text)
    res_co = re.findall(r"(?<=Co of Residence:)(.*?)(?=Military Status:)", text)
    military = re.findall(r"(?<=Military Status:)(.*?)(?=\n)", text)
    employment = re.findall(r"(?<=Employment Status:)(.*?)(?=Attended...)", text)
    school = re.findall(r"(?<=Attended school in last 3 mos:)(.*?)(?=\n)", text)
    arrest_no = re.findall(r"(?<=No of arrest in last 30 days:)(.*?)(?=Current...)", text)
    educ = re.findall(r"(?<=Current or highest grade completed:)(.*?)(?=\n)", text)
    prime_prob = re.findall(r"(?<=Primary Problem that led to Recommended Treatment:)(.*?)(?=\n)", text)
    ID_disability = re.findall(r"(?<=Intellectual/Developmental Disability:)(.*?)(?=Medication...)", text)
    compliance = re.findall(r"(?<=Medication Compliance Issues:)(.*?)(?=\n)", text)
    med_instability = re.findall(r"(?<=Medical/Physical Instability:)(.*?)(?=Past...)", text)
    trauma = re.findall(r"(?<=Past Trauma:)(.*?)(?=\n)", text)
    abuse = re.findall(r"(?<=Substance Abuse:)(.*?)(?=Current...)", text)
    current_wd = re.findall(r"(?<=Current Detox/Withdrawal Symptoms:)(.*?)(?=History...)", text)
    history_wd = re.findall(r"(?<=History of Detox/Withdrawal Symptoms:)(.*?)(?=\n)", text)
    drug = re.findall(r"(?<=Drug:)(.*?)(?=Route:)", text)
    route = re.findall(r"(?<=Route:)(.*?)(?=Frequency:)", text)
    frequency = re.findall(r"(?<=Frequency:)(.*?)(?=\n)", text)
    transport = re.findall(r"(?<=Recommended mode of Transport:)(.*?)(?=\n)", text)
    disp_completed = re.findall(r"(?<=Date/Time Disposition Completed:)(.*?)(?=Date/Transported...)", text)
    rec_facility = re.findall(r"(?<=Date/Transported to receiving facility:)(.*?)(?=\n)", text)
    assessed_by = re.findall(r"(?<=Assessment Completed By:)(.*?)(?=\n)", text)
    contacted = re.findall(r"(?<=Contacted)(.*?)(?=Was Patient...)", text)
    admitted = re.findall(r"(?<=Was Patient Admitted)(.*?)(?=Reported...)", text)
    helpful = re.findall(r"(?<=Reported Services Helpful:)(.*?)(?=Number...)", text)
    num_attempts = re.findall(r"(?<=Number of attempts to contact:)(.*?)(?=\n)", text)
    create = re.findall(r"(?<=Assessment Record Created:)(.*?)(?=\n)", text)
df = pd.DataFrame([first_name, last_name, DOB, gender, race, pro_pat_id, SSN, ethnicity, call_end, disposition, dispatch, 
                   ass_date, arrival, location, LE_transport, televideo, payor_source_prime, current_srvcs, payor_source_sec, mh_treat,
                  hh_income, MOT, ppl_hh, poa, res_stat, marital, res_co, military, employment, school, arrest_no, educ, prime_prob,
                  ID_disability, compliance, med_instability, trauma, abuse, current_wd, history_wd, drug, route, frequency,
                  transport, disp_completed, rec_facility, assessed_by, contacted, admitted, helpful, num_attempts, create])
print(df)
# Out:
#                                                  0
# 0                                       Nathaniel
# 1                                           Barry
# 2                                      07/11/1962
# 3                                             Male
# 4                          Black/African American
# 5
# 6                                       489748518
# 7                           Not of Hispanic Origin
# 8                              03/01/2020 2:00 am
# 9    Mobile crisis staff sent to off-site location
# 10                              03/01/2020 2:01 am
# 11                                     03/01/2020
# 12                                       = 2:38am
# 13                                   Jail or other
# 14                                            YES
# 15                                              NO
# 16                                       Other ey
# 17                                            None
# 18                               HUmMond MediCoid
# 19                                              No
# 20                                            None
# 21                                              No
# 22                                              :
# 23                                            . No
# 24                  Private Residence-Independent
# 25                                   Never Married
# 26                                          Henry
# 27                                            None
# 28                   Disabled, Not in labor force
# 29                                              No
# 30                                            None
# 31
# 32                                            None
# 33                                            None
# 34                                             Yes
# 35                                            None
# 36                                             Yes
# 37                                            Yes
# 38                                             No
# 39                                              No
# 40                                            None
# 41                                            None
# 42                          3-6 Times in Past Week
# 43                                           Other
# 44                              03/01/2020 4:30AM
# 45                               03/01/2020 4:30AM
# 46                                  Joshua Douglas
# 47                                            Yes
# 48                                            None
# 49                                            Yes
# 50                                            None
# 51                              3/1/2020 4:17:08AM

# %%
import pandas as pd
import pytesseract
from PIL import Image
import os
import re
import csv
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
import glob

images = glob.glob("D:/encounters/2020_03/*.tif")
iter_obj = iter(images)

def abbey():
    while True:
        try:
            encounter = next(iter_obj)
            with open(encounter, 'rb') as file:
                img = Image.open(file)
                output = pytesseract.image_to_string(img)
                with open('D:/data/Abbey.txt', 'w', encoding='utf-8') as file:
                    file.write(output)
        except StopIteration:
            break
abbey()

with open('D:/data/Abbey.txt', 'r') as file:
    text=file.read()
    first_name = re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text)
    last_name = re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text)
    DOB = re.findall(r"(?<=DOB:)(.*?)(?=Gender:)", text)
    gender = re.findall(r"(?<=Gender:)(.*?)(?=\n)", text)
    race = re.findall(r"(?<=Race:)(.*?)(?=Provider Pat ID:)", text)
    pro_pat_id = re.findall(r"(?<=Provider Pat ID:)(.*?)(?=\n)", text)
    SSN = re.findall(r"(?<=\n)(.*?)(?=Ethnicity:)", text) 
    ethnicity = re.findall(r"(?<=Ethnicity:)(.*?)(?=\n)", text)
    call_end = re.findall(r"(?<=Call End Date/Time:)(.*?)(?=Disposition:)", text)
    disposition = re.findall(r"(?<=Disposition:)(.*?)(?=\n)", text)
    dispatch = re.findall(r"(?<=Dispatch Date/Time:)(.*?)(?=\n)", text)
    ass_date = re.findall(r"(?<=Assessment Date:)(.*?)(?=Arrival Time:)", text)
    arrival = re.findall(r"(?<=Arrival Time:)(.*?)(?=Consumer)", text)
    location = re.findall(r"(?<=Consumer Location at Assessment:)(.*?)(?=\n)", text)
    LE_transport = re.findall(r"(?<=Transported by Law Enforcement:)(.*?)(?=Crisis...)", text)
    televideo = re.findall(r"(?<=Crisis Assessment via Televideo:)(.*?)(?=\n)", text)
    payor_source_prime = re.findall(r"(?<=Payor Source, Primary:)(.*?)(?=Current...)", text)
    current_srvcs = re.findall(r"(?<=Current Services being Received:)(.*?)(?=\n)", text)
    payor_source_sec = re.findall(r"(?<=Payor Source, Secondary:)(.*?)(?=Declaration...)", text)
    mh_treat = re.findall(r"(?<=Declaration of MH Treatment:)(.*?)(?=\n)", text)
    hh_income = re.findall(r"(?<=Annual Gross HH Income:)(.*?)(?=Durable...)", text)
    MOT = re.findall(r"(?<=MOT Status:)(.*?)(?=\n)", text)
    ppl_hh = re.findall(r"(?<=No. of People in HH)(.*?)(?=Durable...)", text)
    poa = re.findall(r"(?<=Durable POA/Conservator/Guardian:)(.*?)(?=\n)", text)
    res_stat = re.findall(r"(?<=Residential Status:)(.*?)(?=Marital Status)", text)
    marital = re.findall(r"(?<=Marital Status:)(.*?)(?=\n)", text)
    res_co = re.findall(r"(?<=Co of Residence:)(.*?)(?=Military Status:)", text)
    military = re.findall(r"(?<=Military Status:)(.*?)(?=\n)", text)
    employment = re.findall(r"(?<=Employment Status:)(.*?)(?=Attended...)", text)
    school = re.findall(r"(?<=Attended school in last 3 mos:)(.*?)(?=\n)", text)
    arrest_no = re.findall(r"(?<=No of arrest in last 30 days:)(.*?)(?=Current...)", text)
    educ = re.findall(r"(?<=Current or highest grade completed:)(.*?)(?=\n)", text)
    prime_prob = re.findall(r"(?<=Primary Problem that led to Recommended Treatment:)(.*?)(?=\n)", text)
    ID_disability = re.findall(r"(?<=Intellectual/Developmental Disability:)(.*?)(?=Medication...)", text)
    compliance = re.findall(r"(?<=Medication Compliance Issues:)(.*?)(?=\n)", text)
    med_instability = re.findall(r"(?<=Medical/Physical Instability:)(.*?)(?=Past...)", text)
    trauma = re.findall(r"(?<=Past Trauma:)(.*?)(?=\n)", text)
    abuse = re.findall(r"(?<=Substance Abuse:)(.*?)(?=Current...)", text)
    current_wd = re.findall(r"(?<=Current Detox/Withdrawal Symptoms:)(.*?)(?=History...)", text)
    history_wd = re.findall(r"(?<=History of Detox/Withdrawal Symptoms:)(.*?)(?=\n)", text)
    drug = re.findall(r"(?<=Drug:)(.*?)(?=Route:)", text)
    route = re.findall(r"(?<=Route:)(.*?)(?=Frequency:)", text)
    frequency = re.findall(r"(?<=Frequency:)(.*?)(?=\n)", text)
    transport = re.findall(r"(?<=Recommended mode of Transport:)(.*?)(?=\n)", text)
    disp_completed = re.findall(r"(?<=Date/Time Disposition Completed:)(.*?)(?=Date/Transported...)", text)
    rec_facility = re.findall(r"(?<=Date/Transported to receiving facility:)(.*?)(?=\n)", text)
    assessed_by = re.findall(r"(?<=Assessment Completed By:)(.*?)(?=\n)", text)
    contacted = re.findall(r"(?<=Contacted)(.*?)(?=Was Patient...)", text)
    admitted = re.findall(r"(?<=Was Patient Admitted)(.*?)(?=Reported...)", text)
    helpful = re.findall(r"(?<=Reported Services Helpful:)(.*?)(?=Number...)", text)
    num_attempts = re.findall(r"(?<=Number of attempts to contact:)(.*?)(?=\n)", text)
    create = re.findall(r"(?<=Assessment Record Created:)(.*?)(?=\n)", text)
df = pd.DataFrame([first_name, last_name, DOB, gender, race, pro_pat_id, SSN, ethnicity, call_end, disposition, dispatch, 
                   ass_date, arrival, location, LE_transport, televideo, payor_source_prime, current_srvcs, payor_source_sec, mh_treat,
                  hh_income, MOT, ppl_hh, poa, res_stat, marital, res_co, military, employment, school, arrest_no, educ, prime_prob,
                  ID_disability, compliance, med_instability, trauma, abuse, current_wd, history_wd, drug, route, frequency,
                  transport, disp_completed, rec_facility, assessed_by, contacted, admitted, helpful, num_attempts, create])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[100], line 27
#      24 abbey()
#      26 with open('D:/data/Abbey.txt', 'r+') as file:
# ---> 27     text=file.read()
#      28     first_name = re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text)
#      29     last_name = re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 54654: character maps to <undefined>

# %%
## SUPER MEGA HAPPY WITH THIS ONE

import pandas as pd
import pytesseract
from PIL import Image
import os
import re
import csv
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
import glob
import stat

images = glob.glob("D:/encounters/2020_04/*.tif")
count = len(images)
iter_obj = iter(images)
output_directory = "D:/data/2020_04/"

if not os.path.exists(output_directory):
        os.makedirs(output_directory)
for i in range(count):
    output_filename = os.path.join(output_directory, f"Abbey_{i+1}.txt")
    if not os.path.exists(output_filename):
        open(output_filename, 'w')    
file_list = glob.glob("D:/data/2020_04/*.txt")
iter_file = iter(file_list)


def abbey():
    while True:
        try:
            encounter = next(iter_obj)
            with open(encounter, 'rb') as image:
                img = Image.open(image)
                output = pytesseract.image_to_string(img)
                def write_output():
                    next_file = next(iter_file)
                    with open(next_file, 'a+') as file:
                        file.write(f'File: {encounter}\n\n{output}')
                write_output()
        except StopIteration:
            break
abbey()
## SUPER MEGA HAPPY WITH THIS ONE

# %%
import pandas as pd
import pytesseract
from PIL import Image
import os
import re
import csv
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
import glob
import pickle

files = glob.glob('D:/data/2020_03_final/*.txt')
iter_file = iter(files)
results = []
first_name.clear()
last_name.clear()
DOB.clear()
gender.clear()
race.clear()
pro_pat_id.clear()
SSN.clear()
ethnicity.clear()
call_end.clear()
disposition.clear()
dispatch.clear()
ass_date.clear()
arrival.clear()
location.clear()
LE_transport.clear()
televideo.clear()
payor_source_prime.clear()
current_srvcs.clear()
payor_source_sec.clear()
mh_treat.clear()
hh_income.clear()
MOT.clear()
ppl_hh.clear()
poa.clear()
res_stat.clear()
marital.clear()
res_co.clear()
military.clear()
employment.clear()
school.clear()
arrest_no.clear()
educ.clear()
prime_prob.clear()
ID_disability.clear()
compliance.clear()
med_instability.clear()
trauma.clear()
abuse.clear()
current_wd.clear()
history_wd.clear()
drug.clear()
route.clear()
frequency.clear()
transport.clear()
disp_completed.clear()
rec_facility.clear()
assessed_by.clear()
contacted.clear()
admitted.clear()
helpful.clear()
num_attempts.clear()
create.clear()

index = 0
while True:
    try:
        filename = next(iter_file)    
        with open(filename, 'r') as file:
            text=file.read()
        first_name += re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text) or ["Error"]
        last_name += re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text) or ["Error"]
        DOB += re.findall(r"(?<=DOB:)(.*?)(?=Gender:)", text) or ["Error"]
        gender += re.findall(r"(?<=Gender:)(.*?)(?=\n)", text) or ["Error"]
        race += re.findall(r"(?<=Race:)(.*?)(?=Provider Pat ID:)", text) or ['Error']
        pro_pat_id += re.findall(r"(?<=Provider Pat ID:)(.*?)(?=\n)", text) or ['Error']
        SSN += re.findall(r"(?<=\n)(.*?)(?=Ethnicity:)", text) or ["Error"]
        ethnicity += re.findall(r"(?<=Ethnicity:)(.*?)(?=\n)", text) or ['Error']
        call_end += re.findall(r"(?<=Call End Date/Time:)(.*?)(?=Disposition:)", text) or ['Error']
        disposition += re.findall(r"(?<=Disposition:)(.*?)(?=\n)", text) or ['Error']
        dispatch += re.findall(r"(?<=Dispatch Date/Time:)(.*?)(?=\n)", text) or ['Error']
        ass_date += re.findall(r"(?<=Assessment Date:)(.*?)(?=Arrival Time:)", text) or ['Error']
        arrival += re.findall(r"(?<=Arrival Time:)(.*?)(?=Consumer)", text) or ['Error']
        location += re.findall(r"(?<=Consumer Location at Assessment:)(.*?)(?=\n)", text) or ['Error']
        LE_transport += re.findall(r"(?<=Transported by Law Enforcement:)(.*?)(?=Crisis...)", text) or ['Error']
        televideo += re.findall(r"(?<=Crisis Assessment via Televideo:)(.*?)(?=\n)", text) or ['Error']
        payor_source_prime += re.findall(r"(?<=Payor Source, Primary:)(.*?)(?=Current...)", text) or ['Error']
        current_srvcs += re.findall(r"(?<=Current Services being Received:)(.*?)(?=\n)", text) or ['Error']
        payor_source_sec += re.findall(r"(?<=Payor Source, Secondary:)(.*?)(?=Declaration...)", text) or ['Error']
        mh_treat += re.findall(r"(?<=Declaration of MH Treatment:)(.*?)(?=\n)", text) or ['Error']
        hh_income += re.findall(r"(?<=Annual Gross HH Income:)(.*?)(?=Durable...)", text) or ['Error']
        MOT += re.findall(r"(?<=MOT Status:)(.*?)(?=\n)", text) or ['Error']
        ppl_hh += re.findall(r"(?<=No. of People in HH)(.*?)(?=Durable...)", text) or ['Error']
        poa += re.findall(r"(?<=Durable POA/Conservator/Guardian:)(.*?)(?=\n)", text) or ['Error']
        res_stat += re.findall(r"(?<=Residential Status:)(.*?)(?=Marital Status)", text) or ['Error']
        marital += re.findall(r"(?<=Marital Status:)(.*?)(?=\n)", text) or ['Error']
        res_co += re.findall(r"(?<=Co of Residence:)(.*?)(?=Military Status:)", text) or ['Error']
        military += re.findall(r"(?<=Military Status:)(.*?)(?=\n)", text) or ['Error']
        employment += re.findall(r"(?<=Employment Status:)(.*?)(?=Attended...)", text) or ['Error']
        school += re.findall(r"(?<=Attended school in last 3 mos:)(.*?)(?=\n)", text) or ['Error']
        arrest_no += re.findall(r"(?<=No of arrest in last 30 days:)(.*?)(?=Current...)", text) or ['Error']
        educ += re.findall(r"(?<=Current or highest grade completed:)(.*?)(?=\n)", text) or ['Error']
        prime_prob += re.findall(r"(?<=Primary Problem that led to Recommended Treatment:)(.*?)(?=\n)", text) or ['Error']
        ID_disability += re.findall(r"(?<=Intellectual/Developmental Disability:)(.*?)(?=Medication...)", text) or ['Error']
        compliance += re.findall(r"(?<=Medication Compliance Issues:)(.*?)(?=\n)", text) or ['Error']
        med_instability += re.findall(r"(?<=Medical/Physical Instability:)(.*?)(?=Past...)", text) or ['Error']
        trauma += re.findall(r"(?<=Past Trauma:)(.*?)(?=\n)", text) or ['Error']
        abuse += re.findall(r"(?<=Substance Abuse:)(.*?)(?=Current...)", text) or ['Error']
        current_wd += re.findall(r"(?<=Current Detox/Withdrawal Symptoms:)(.*?)(?=History...)", text) or ['Error']
        history_wd += re.findall(r"(?<=History of Detox/Withdrawal Symptoms:)(.*?)(?=\n)", text) or ['Error']
        drug += re.findall(r"(?<=Drug:)(.*?)(?=Route:)", text) or ['Error']
        route += re.findall(r"(?<=Route:)(.*?)(?=Frequency:)", text) or ['Error']
        frequency += re.findall(r"(?<=Frequency:)(.*?)(?=\n)", text) or ['Error']
        transport += re.findall(r"(?<=Recommended mode of Transport:)(.*?)(?=\n)", text) or ['Error']
        disp_completed += re.findall(r"(?<=Date/Time Disposition Completed:)(.*?)(?=Date/Transported...)", text) or ['Error']
        rec_facility += re.findall(r"(?<=Date/Transported to receiving facility:)(.*?)(?=\n)", text) or ['Error']
        assessed_by += re.findall(r"(?<=Assessment Completed By:)(.*?)(?=\n)", text) or ['Error']
        contacted += re.findall(r"(?<=Contacted)(.*?)(?=Was Patient...)", text) or ['Error']
        admitted += re.findall(r"(?<=Was Patient Admitted)(.*?)(?=Reported...)", text) or ['Error']
        helpful += re.findall(r"(?<=Reported Services Helpful:)(.*?)(?=Number...)", text) or ['Error']
        num_attempts += re.findall(r"(?<=Number of attempts to contact:)(.*?)(?=\n)", text) or ['Error']
        create += re.findall(r"(?<=Assessment Record Created:)(.*?)(?=\n)", text) or ['Error']
        results.append({'First Name': first_name, 'Last Name': last_name, 'Date of Birth': DOB, 'Gender':gender,
                       'Race':race, 'pro_pat_id':pro_pat_id, 'SSN':SSN, 'ethnicity':ethnicity, 'call_end':call_end, 'disposition':disposition, 
                       'Dispatch':dispatch, 'ass_date':ass_date, 'arrival':arrival, 'location':location, 'LE_transport':LE_transport, 'televideo':
                       televideo, 'payor_source_prime':payor_source_prime, 'current svcs':current_srvcs, 'payro_source_sec':payor_source_sec, 
                       'mh_treat':mh_treat, 'hh_income':hh_income, 'MOT':MOT, 'pp_hh':ppl_hh, 'poa':poa, 'res_stat':res_stat, 'marital':marital, 
                       'res_co':res_co, 'military':military, 'employment':employment, 'school':school, 'arrest_no':arrest_no, 'educ':educ, 
                       'prime_prob':prime_prob, 'ID_Disability':ID_disability, 'compliance':compliance, 'med_instability':med_instability, 
                       'trauma':trauma, 'abuse':abuse, 'current_wd':current_wd, 'history_wd':history_wd,  
                       'transport':transport, 'disp_completed':disp_completed, 'rec_facility':rec_facility, 'assessed_by':assessed_by, 'contacted':
                       contacted, 'admitted':admitted, 'helpful':helpful, 'num_attempts':num_attempts, 'create':create})                
    except StopIteration:
        break
                

        
print(len(first_name), len(last_name), len(DOB), len(gender), len(race), len(pro_pat_id), len(SSN), len(ethnicity), len(call_end), len(disposition), 
      len(dispatch), len(ass_date), len(arrival), len(location), len(LE_transport), len(televideo), len(payor_source_prime), len(current_srvcs), 
      len(payor_source_sec), len(mh_treat), len(hh_income), len(MOT), len(ppl_hh), len(poa), len(res_stat), len(marital), len(res_co), len(military), 
      len(employment), len(school), len(arrest_no), len(educ), len(prime_prob), len(ID_disability), len(compliance), len(med_instability), len(trauma), 
      len(abuse), len(current_wd), len(history_wd), len(drug), len(route), len(frequency), len(transport), len(disp_completed), len(rec_facility), 
      len(assessed_by), len(contacted), len(admitted), len(helpful), len(num_attempts), len(create))

results_df = pd.concat([pd.DataFrame(item) for item in results])
results_df.head()


            # index = pd.Index(['first_name', 'last_name', 'DOB', 'gender', 'race', 'pro_pat_id', 'SSN', 'ethnicity', 'call_end', 'disposition', 'dispatch', 
    #              'ass_date', 'arrival', 'location', 'LE_transport', 'televideo', 'payor_source_prime', 'current_srvcs', 'payor_source_sec', 'mh_treat', 
    #              'hh_income', 'MOT', 'ppl_hh', 'poa', 'res_stat', 'marital', 'res_co', 'military', 'employment', 'school', 'arrest_no', 'educ', 'prime_prob',
     #             'ID_disability', 'compliance', 'med_instability', 'trauma', 'abuse', 'current_wd', 'history_wd', 'drug', 'route', 'frequency', 
   #               'transport', 'disp_completed', 'rec_facility', 'assessed_by', 'contacted', 'admitted', 'helpful', 'num_attempts', 'create'])

#df = df.set_index([index])
# Out:
# 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 88 90 90 95 88 88 88 88 88 88 88 88 88
#     First Name   Last Name Date of Birth     Gender                      Race  \
# 0   Nathaniel       Barry    07/11/1962        Male   Black/African American
# 1        Error       Error         Error       Male                    White
# 2     Rebecca       Clark    10/21/1989    — Female        Not Collected Wht
# 3     Whitney    Sutherby          Error     Female                     Error
# 4        Lois     Nesbitt                  — Female   Black/African American
#
#   pro_pat_id                SSN                ethnicity  \
# 0               SSN: 489748518    Not of Hispanic Origin
# 1                                 Not of Hispanic Origin
# 2                         Error                    Error
# 3             | SSN: 411812179    Not of Hispanic Origin
# 4             [ SSN: 410171272    Not of Hispanic Origin
#
#                call_end                                     disposition  ...  \
# 0   03/01/2020 2:00 am    Mobile crisis staff sent to off-site location  ...
# 1                 Error                                                  ...
# 2                         Mobile crisis staff sent to off-site location  ...
# 3   03/05/2020 1:23 am                                                   ...
# 4   03/05/2020 4:30 pm    Mobile crisis staff sent to off-site location  ...
#
#   history_wd         transport        disp_completed         rec_facility  \
# 0         No             Other    03/01/2020 4:30AM     03/01/2020 4:30AM
# 1         No             Error                 Error   03/04/2020 11:05PM
# 2         No             Other   03/04/2020 11:15PM
# 3         No   Law Enforcement    03/05/2020 6:16AM     03/05/2020 6:16AM
# 4         No   Law Enforcement                 Error
#
#        assessed_by contacted admitted helpful num_attempts  \
# 0   Joshua Douglas      Yes     Error    Yes         Error
# 1   Joshua Douglas     Error    Error   Error        Error
# 2      Amanda Wood      Yes     Error    Yes         Error
# 3   Joshua Douglas      Yes     Error    Yes         Error
# 4            Error     Error    Error   Error        Error
#
#                  create
# 0    3/1/2020 4:17:08AM
# 1   3/4/2020 10:36:21PM
# 2   3/4/2020 10:58:11PM
# 3    3/5/2020 4:18:27AM
# 4    3/5/2020 6:58:08PM
#
# [5 rows x 49 columns]

# %%
## THIS IS THE WAY

import pandas as pd
import os
import re
import csv
import glob

files = glob.glob('D:/data/2020_04/*.txt')
#iter_file = iter(files)
results = []
#file_path.clear()
#first_name.clear()
#last_name.clear()
#DOB.clear()
#gender.clear()
#race.clear()
#pro_pat_id.clear()
#SSN.clear()
#ethnicity.clear()
#call_end.clear()
#disposition.clear()
#dispatch.clear()
#ass_date.clear()
#arrival.clear()
#location.clear()
#LE_transport.clear()
#televideo.clear()
#payor_source_prime.clear()
#current_srvcs.clear()
#payor_source_sec.clear()
#mh_treat.clear()
#hh_income.clear()
#MOT.clear()
#ppl_hh.clear()
#poa.clear()
#res_stat.clear()
#marital.clear()
#res_co.clear()
#military.clear()
#employment.clear()
#school.clear()
#arrest_no.clear()
#educ.clear()
#prime_prob.clear()
#ID_disability.clear()
#compliance.clear()
#med_instability.clear()
#trauma.clear()
#abuse.clear()
#current_wd.clear()
#history_wd.clear()
#transport.clear()
#disp_completed.clear()
#rec_facility.clear()
#assessed_by.clear()
#contacted.clear()
#admitted.clear()
#helpful.clear()
#num_attempts.clear()
#create.clear()
#route.clear()
#frequency.clear()
#drug.clear()
#referral.clear()
#voluntary.clear()
#telehealth.clear()
#first_hosp.clear()

file_list = glob.glob("D:/data/2020_04/*.txt")
for file in file_list:
    with open(file, 'r') as f:
        text=f.read()
        file_path = re.findall(r"(?<=File:)(.*?)(?=\n)", text) or ['NA']
        first_name = re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text) or ["NA"]
        last_name = re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text) or ["NA"]
        DOB = re.findall(r"(?<=DOB:)(.*?)(?=Gender:)", text) or ["NA"]
        gender = re.findall(r"(?<=Gender:)(.*?)(?=\n)", text) or ["NA"]
        race = re.findall(r"(?<=Race:)(.*?)(?=Provider Pat ID:)", text) or ['NA']
        pro_pat_id = re.findall(r"(?<=Provider Pat ID:)(.*?)(?=\n)", text) or ['NA']
        SSN = re.findall(r"(?<=\n)(.*?)(?=Ethnicity:)", text) or ["NA"]
        ethnicity = re.findall(r"(?<=Ethnicity:)(.*?)(?=\n)", text) or ['NA']
        call_end = re.findall(r"(?<=Call End Date/Time:)(.*?)(?=Disposition:)", text) or ['NA']
        disposition = re.findall(r"(?<=Disposition:)(.*?)(?=\n)", text) or ['NA']
        dispatch = re.findall(r"(?<=Dispatch Date/Time:)(.*?)(?=\n)", text) or ['NA']
        ass_date = re.findall(r"(?<=Assessment Date:)(.*?)(?=Arrival Time:)", text) or ['NA']
        arrival = re.findall(r"(?<=Arrival Time:)(.*?)(?=Consumer)", text) or ['NA']
        location = re.findall(r"(?<=Consumer Location at Assessment:)(.*?)(?=\n)", text) or ['NA']
        LE_transport = re.findall(r"(?<=Transported by Law Enforcement:)(.*?)(?=Crisis...)", text) or ['NA']
        televideo = re.findall(r"(?<=Crisis Assessment via Televideo:)(.*?)(?=\n)", text) or ['NA']
        payor_source_prime = re.findall(r"(?<=Payor Source, Primary:)(.*?)(?=Current...)", text) or ['NA']
        current_srvcs = re.findall(r"(?<=Current Services being Received:)(.*?)(?=\n)", text) or ['NA']
        payor_source_sec = re.findall(r"(?<=Payor Source, Secondary:)(.*?)(?=Declaration...)", text) or ['NA']
        mh_treat = re.findall(r"(?<=Declaration of MH Treatment:)(.*?)(?=\n)", text) or ['NA']
        hh_income = re.findall(r"(?<=Annual Gross HH Income:)(.*?)(?=Durable...)", text) or ['NA']
        MOT = re.findall(r"(?<=MOT Status:)(.*?)(?=\n)", text) or ['NA']
        ppl_hh = re.findall(r"(?<=No. of People in HH)(.*?)(?=Durable...)", text) or ['NA']
        poa = re.findall(r"(?<=Durable POA/Conservator/Guardian:)(.*?)(?=\n)", text) or ['NA']
        res_stat = re.findall(r"(?<=Residential Status:)(.*?)(?=Marital Status)", text) or ['NA']
        marital = re.findall(r"(?<=Marital Status:)(.*?)(?=\n)", text) or ['NA']
        res_co = re.findall(r"(?<=Co of Residence:)(.*?)(?=Military Status:)", text) or ['NA']
        military = re.findall(r"(?<=Military Status:)(.*?)(?=\n)", text) or ['NA']
        employment = re.findall(r"(?<=Employment Status:)(.*?)(?=Attended...)", text) or ['NA']
        school = re.findall(r"(?<=Attended school in last 3 mos:)(.*?)(?=\n)", text) or ['NA']
        arrest_no = re.findall(r"(?<=No of arrest in last 30 days:)(.*?)(?=Current...)", text) or ['NA']
        educ = re.findall(r"(?<=Current or highest grade completed:)(.*?)(?=\n)", text) or ['NA']
        prime_prob = re.findall(r"(?<=Primary Problem that led to Recommended Treatment:)(.*?)(?=\n)", text) or ['NA']
        ID_disability = re.findall(r"(?<=Intellectual/Developmental Disability:)(.*?)(?=Medication...)", text) or ['NA']
        compliance = re.findall(r"(?<=Medication Compliance Issues:)(.*?)(?=\n)", text) or ['NA']
        med_instability = re.findall(r"(?<=Medical/Physical Instability:)(.*?)(?=Past...)", text) or ['NA']
        trauma = re.findall(r"(?<=Past Trauma:)(.*?)(?=\n)", text) or ['NA']
        abuse = re.findall(r"(?<=Substance Abuse:)(.*?)(?=Current...)", text) or ['NA']
        current_wd = re.findall(r"(?<=Current Detox/Withdrawal Symptoms:)(.*?)(?=History...)", text) or ['NA']
        history_wd = re.findall(r"(?<=History of Detox/Withdrawal Symptoms:)(.*?)(?=\n)", text) or ['NA']
        drug = re.findall(r"(?<=Drug:)(.*?)(?=Route:)", text) or ['NA']
        route = re.findall(r"(?<=Route:)(.*?)(?=Frequency:)", text) or ['NA']
        frequency = re.findall(r"(?<=Frequency:)(.*?)(?=\n)", text) or ['NA']
        transport = re.findall(r"(?<=Recommended mode of Transport:)(.*?)(?=\n)", text) or ['NA']
        disp_completed = re.findall(r"(?<=Date/Time Disposition Completed:)(.*?)(?=Date/Transported...)", text) or ['NA']
        rec_facility = re.findall(r"(?<=Date/Transported to receiving facility:)(.*?)(?=\n)", text) or ['NA']
        assessed_by = re.findall(r"(?<=Assessment Completed By:)(.*?)(?=\n)", text) or ['NA']
        contacted = re.findall(r"(?<=Contacted)(.*?)(?=Was Patient...)", text) or ['NA']
        admitted = re.findall(r"(?<=Was Patient Admitted)(.*?)(?=Reported...)", text) or ['NA']
        helpful = re.findall(r"(?<=Reported Services Helpful:)(.*?)(?=Number...)", text) or ['NA']
        num_attempts = re.findall(r"(?<=Number of attempts to contact:)(.*?)(?=\n)", text) or ['NA']
        create = re.findall(r"(?<=Assessment Record Created:)(.*?)(?=\n)", text) or ['NA']
        referral = re.findall(r"(?<=\n)(.*?)(?=Referral Accepted)", text) or ['NA']
        voluntary = re.findall(r"(?<=Voluntary Admission Recommended)(.*?)(?=Admission...)", text) or ['NA']
        telehealth = re.findall(r"(?<=Admission Assessment via Telehealth)(.*?)(?=1st...)", text) or ['NA']
        first_hosp = re.findall(r"(?<=1st Hospitalization)(.*?)(?=\n)", text) or ['NA']
    results.append({'File path': file_path, 'First Name': first_name, 'Last Name': last_name, 'Date of Birth': DOB, 'Gender':gender,
                       'Race':race, 'pro_pat_id':pro_pat_id, 'SSN':SSN, 'ethnicity':ethnicity, 'call_end':call_end, 'disposition':disposition, 
                       'Dispatch':dispatch, 'ass_date':ass_date, 'arrival':arrival, 'location':location, 'LE_transport':LE_transport, 'televideo':
                        televideo, 'payor_source_prime':payor_source_prime, 'current svcs':current_srvcs, 'payro_source_sec':payor_source_sec, 
                       'mh_treat':mh_treat, 'hh_income':hh_income, 'MOT':MOT, 'pp_hh':ppl_hh, 'poa':poa, 'res_stat':res_stat, 'marital':marital, 
                       'res_co':res_co, 'military':military, 'employment':employment, 'school':school, 'arrest_no':arrest_no, 'educ':educ, 
                       'prime_prob':prime_prob, 'ID_Disability':ID_disability, 'compliance':compliance, 'med_instability':med_instability, 
                       'trauma':trauma, 'abuse':abuse, 'current_wd':current_wd, 'history_wd':history_wd,  'drug':drug, 'route':route, 'freq':frequency,
                       'transport':transport, 'disp_completed':disp_completed, 'rec_facility':rec_facility, 'assessed_by':assessed_by, 'contacted':
                       contacted, 'admitted':admitted, 'helpful':helpful, 'num_attempts':num_attempts, 'create':create, 'referral':referral,
                       'voluntary':voluntary, 'telehealth':telehealth, 'first hospitalization':first_hosp})                
    #except StopIteration:
break
        
print(len(file_path), len(first_name), len(last_name), len(DOB), len(gender), len(race), len(pro_pat_id), len(SSN), len(ethnicity), len(call_end), len(disposition), 
      len(dispatch), len(ass_date), len(arrival), len(location), len(LE_transport), len(televideo), len(payor_source_prime), len(current_srvcs), 
      len(payor_source_sec), len(mh_treat), len(hh_income), len(MOT), len(ppl_hh), len(poa), len(res_stat), len(marital), len(res_co), len(military), 
      len(employment), len(school), len(arrest_no), len(educ), len(prime_prob), len(ID_disability), len(compliance), len(med_instability), len(trauma), 
      len(abuse), len(current_wd), len(history_wd), len(drug), len(route), len(frequency), len(transport), len(disp_completed), len(rec_facility), 
      len(assessed_by), len(contacted), len(admitted), len(helpful), len(num_attempts), len(create), len(referral), len(voluntary), len(telehealth),
      len(first_hosp))

results_df_2020_04 = pd.concat([pd.DataFrame(item) for item in results])
results_df_2020_04.head()

## THIS IS THE WAY?
# Out:
#   Cell In[98], line 143
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
## THIS IS THE WAY? maybe 11:22 pm 3/20/2024

import pandas as pd
import os
import re
import csv
import glob

results = []
file_path = []
first_name =[]
last_name = []
DOB = []
gender = []
race = []
pro_pat_id = []
SSN = []
ethnicity = []
call_end = []
disposition = []
dispatch = []
ass_date = []
arrival = []
location = []
LE_transport = []
televideo = []
payor_source_prime = []
current_srvcs = []
payor_source_sec = []
mh_treat = []
hh_income = []
MOT = []
ppl_hh = []
poa = []
res_stat = []
marital = []
res_co = []
military = []
employment = []
school = []
arrest_no = []
educ = []
prime_prob = []
ID_disability = []
compliance = []
med_instability = []
trauma = []
abuse = []
current_wd = []
history_wd = []
drug = []
route = []
frequency = []
transport = []
disp_completed = []
rec_facility = []
assessed_by = []
contacted = []
admitted = []
helpful = []
num_attempts = []
create = []
referral = []
voluntary = []
telehealth = []
first_hosp = []

file_list = glob.glob("D:/data/2020_04/*.txt")
for file in file_list:
    with open(file, 'r') as f:
        text=f.read()
        file_path += re.findall(r"(?<=File:)(.*?)(?=\n)", text) or ['NA'],
        first_name += re.findall(r"(?<=First Name:)(.*?)(?=DOB:)", text) or ["NA"],
        last_name += re.findall(r"(?<=Last Name:)(.*?)(?=Race:)", text) or ["NA"],
        DOB += re.findall(r"(?<=DOB:)(.*?)(?=Gender:)", text) or ["NA"],
        gender += re.findall(r"(?<=Gender:)(.*?)(?=\n)", text) or ["NA"],
        race += re.findall(r"(?<=Race:)(.*?)(?=Provider Pat ID:)", text) or ['NA'],
        pro_pat_id += re.findall(r"(?<=Provider Pat ID:)(.*?)(?=\n)", text) or ['NA'],
        SSN += re.findall(r"(?<=\n)(.*?)(?=Ethnicity:)", text) or ["NA"],
        ethnicity += re.findall(r"(?<=Ethnicity:)(.*?)(?=\n)", text) or ['NA'],
        call_end += re.findall(r"(?<=Call End Date/Time:)(.*?)(?=Disposition:)", text) or ['NA'],
        disposition += re.findall(r"(?<=Disposition:)(.*?)(?=\n)", text) or ['NA'],
        dispatch += re.findall(r"(?<=Dispatch Date/Time:)(.*?)(?=\n)", text) or ['NA'],
        ass_date += re.findall(r"(?<=Assessment Date:)(.*?)(?=Arrival Time:)", text) or ['NA'],
        arrival += re.findall(r"(?<=Arrival Time:)(.*?)(?=Consumer)", text) or ['NA'],
        location += re.findall(r"(?<=Consumer Location at Assessment:)(.*?)(?=\n)", text) or ['NA'],
        LE_transport += re.findall(r"(?<=Transported by Law Enforcement:)(.*?)(?=Crisis...)", text) or ['NA'],
        televideo += re.findall(r"(?<=Crisis Assessment via Televideo:)(.*?)(?=\n)", text) or ['NA'],
        payor_source_prime += re.findall(r"(?<=Payor Source, Primary:)(.*?)(?=Current...)", text) or ['NA'],
        current_srvcs += re.findall(r"(?<=Current Services being Received:)(.*?)(?=\n)", text) or ['NA'],
        payor_source_sec += re.findall(r"(?<=Payor Source, Secondary:)(.*?)(?=Declaration...)", text) or ['NA'],
        mh_treat += re.findall(r"(?<=Declaration of MH Treatment:)(.*?)(?=\n)", text) or ['NA'],
        hh_income += re.findall(r"(?<=Annual Gross HH Income:)(.*?)(?=Durable...)", text) or ['NA'],
        MOT += re.findall(r"(?<=MOT Status:)(.*?)(?=\n)", text) or ['NA'],
        ppl_hh += re.findall(r"(?<=No. of People in HH)(.*?)(?=Durable...)", text) or ['NA'],
        poa += re.findall(r"(?<=Durable POA/Conservator/Guardian:)(.*?)(?=\n)", text) or ['NA'],
        res_stat += re.findall(r"(?<=Residential Status:)(.*?)(?=Marital Status)", text) or ['NA'],
        marital += re.findall(r"(?<=Marital Status:)(.*?)(?=\n)", text) or ['NA'],
        res_co += re.findall(r"(?<=Co of Residence:)(.*?)(?=Military Status:)", text) or ['NA'],
        military += re.findall(r"(?<=Military Status:)(.*?)(?=\n)", text) or ['NA'],
        employment += re.findall(r"(?<=Employment Status:)(.*?)(?=Attended...)", text) or ['NA'],
        school += re.findall(r"(?<=Attended school in last 3 mos:)(.*?)(?=\n)", text) or ['NA'],
        arrest_no += re.findall(r"(?<=No of arrest in last 30 days:)(.*?)(?=Current...)", text) or ['NA'],
        educ += re.findall(r"(?<=Current or highest grade completed:)(.*?)(?=\n)", text) or ['NA'],
        prime_prob += re.findall(r"(?<=Primary Problem that led to Recommended Treatment:)(.*?)(?=\n)", text) or ['NA'],
        ID_disability += re.findall(r"(?<=Intellectual/Developmental Disability:)(.*?)(?=Medication...)", text) or ['NA'],
        compliance += re.findall(r"(?<=Medication Compliance Issues:)(.*?)(?=\n)", text) or ['NA'],
        med_instability += re.findall(r"(?<=Medical/Physical Instability:)(.*?)(?=Past...)", text) or ['NA'],
        trauma += re.findall(r"(?<=Past Trauma:)(.*?)(?=\n)", text) or ['NA'],
        abuse += re.findall(r"(?<=Substance Abuse:)(.*?)(?=Current...)", text) or ['NA'],
        current_wd += re.findall(r"(?<=Current Detox/Withdrawal Symptoms:)(.*?)(?=History...)", text) or ['NA'],
        history_wd += re.findall(r"(?<=History of Detox/Withdrawal Symptoms:)(.*?)(?=\n)", text) or ['NA'],
        drug += re.findall(r"(?<=Drug:)(.*?)(?=Route:)", text) or ['NA'],
        route += re.findall(r"(?<=Route:)(.*?)(?=Frequency:)", text) or ['NA'],
        frequency += re.findall(r"(?<=Frequency:)(.*?)(?=\n)", text) or ['NA'],
        transport += re.findall(r"(?<=Recommended mode of Transport:)(.*?)(?=\n)", text) or ['NA'],
        disp_completed += re.findall(r"(?<=Date/Time Disposition Completed:)(.*?)(?=Date/Transported...)", text) or ['NA'],
        rec_facility += re.findall(r"(?<=Date/Transported to receiving facility:)(.*?)(?=\n)", text) or ['NA'],
        assessed_by += re.findall(r"(?<=Assessment Completed By:)(.*?)(?=\n)", text) or ['NA'],
        contacted += re.findall(r"(?<=Contacted)(.*?)(?=Was Patient...)", text) or ['NA'],
        admitted += re.findall(r"(?<=Was Patient Admitted)(.*?)(?=Reported...)", text) or ['NA'],
        helpful += re.findall(r"(?<=Reported Services Helpful:)(.*?)(?=Number...)", text) or ['NA'],
        num_attempts += re.findall(r"(?<=Number of attempts to contact:)(.*?)(?=\n)", text) or ['NA'],
        create += re.findall(r"(?<=Assessment Record Created:)(.*?)(?=\n)", text) or ['NA'],
        referral += re.findall(r"(?<=\n)(.*?)(?=Referral Accepted)", text) or ['NA'],
        voluntary += re.findall(r"(?<=Voluntary Admission Recommended)(.*?)(?=Admission...)", text) or ['NA'],
        telehealth += re.findall(r"(?<=Admission Assessment via Telehealth)(.*?)(?=1st...)", text) or ['NA'],
        first_hosp += re.findall(r"(?<=1st Hospitalization)(.*?)(?=\n)", text) or ['NA']
        results = ({'File path': file_path, 'First Name': first_name, 'Last Name': last_name, 'Date of Birth': DOB, 'Gender':gender,
                       'Race':race, 'pro_pat_id':pro_pat_id, 'SSN':SSN, 'ethnicity':ethnicity, 'call_end':call_end, 'disposition':disposition, 
                       'Dispatch':dispatch, 'ass_date':ass_date, 'arrival':arrival, 'location':location, 'LE_transport':LE_transport, 'televideo':
                        televideo, 'payor_source_prime':payor_source_prime, 'current svcs':current_srvcs, 'payro_source_sec':payor_source_sec, 
                       'mh_treat':mh_treat, 'hh_income':hh_income, 'MOT':MOT, 'pp_hh':ppl_hh, 'poa':poa, 'res_stat':res_stat, 'marital':marital, 
                       'res_co':res_co, 'military':military, 'employment':employment, 'school':school, 'arrest_no':arrest_no, 'educ':educ, 
                       'prime_prob':prime_prob, 'ID_Disability':ID_disability, 'compliance':compliance, 'med_instability':med_instability, 
                       'trauma':trauma, 'abuse':abuse, 'current_wd':current_wd, 'history_wd':history_wd,  'drug':drug, 'route':route, 'freq':frequency,
                       'transport':transport, 'disp_completed':disp_completed, 'rec_facility':rec_facility, 'assessed_by':assessed_by, 'contacted':
                       contacted, 'admitted':admitted, 'helpful':helpful, 'num_attempts':num_attempts, 'create':create, 'referral':referral,
                       'voluntary':voluntary, 'telehealth':telehealth, 'first hospitalization':first_hosp})                
           
#except StopIteration:
        
print(len(file_path), len(first_name), len(last_name), len(DOB), len(gender), len(race), len(pro_pat_id), len(SSN), len(ethnicity), len(call_end), len(disposition), 
      len(dispatch), len(ass_date), len(arrival), len(location), len(LE_transport), len(televideo), len(payor_source_prime), len(current_srvcs), 
      len(payor_source_sec), len(mh_treat), len(hh_income), len(MOT), len(ppl_hh), len(poa), len(res_stat), len(marital), len(res_co), len(military), 
      len(employment), len(school), len(arrest_no), len(educ), len(prime_prob), len(ID_disability), len(compliance), len(med_instability), len(trauma), 
      len(abuse), len(current_wd), len(history_wd), len(drug), len(route), len(frequency), len(transport), len(disp_completed), len(rec_facility), 
      len(assessed_by), len(contacted), len(admitted), len(helpful), len(num_attempts), len(create), len(referral), len(voluntary), len(telehealth),
      len(first_hosp))

df = pd.DataFrame(results)
df.head()
## This time, this IS the WAY, somehow. maybe.
# Out:
# 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71 71
#                               File path  First Name     Last Name  \
# 0   [ D:/encounters/2020_04\page_1.tif]    [ Ross ]  [ Vehikite ]
# 1  [ D:/encounters/2020_04\page_10.tif]  [ Lauren ]      [ Swor ]
# 2  [ D:/encounters/2020_04\page_11.tif]        [NA]   [ Edwards ]
# 3  [ D:/encounters/2020_04\page_12.tif]        [NA]          [NA]
# 4  [ D:/encounters/2020_04\page_13.tif]   [ Ricky ]   [ Newsome ]
#
#         Date of Birth       Gender                        Race pro_pat_id  \
# 0                [NA]  [ — Female]                        [NA]         []
# 1  [ 122K 999 : He, ]  [ — Female]        [ -Not-Colleeted W ]         []
# 2                [NA]      [ Male]                   [ White ]         []
# 3      [ 07/22/1963 ]  [ — Female]  [ Black/African American ]         []
# 4      [ 12/07/1953 ]      [ Male]                 [ Unknown ]         []
#
#                  SSN                    ethnicity call_end  ...  \
# 0       [452965563 ]                           []     [NA]  ...
# 1  [SSN: 413874816 ]        [ Lee # ot isaac Onn]     [NA]  ...
# 2  [SSN: 414456201 ]                           []     [NA]  ...
# 3                 []  [ — Not of Hispanic Origin]     [NA]  ...
# 4  [SSN: 413944341 ]                           []     [NA]  ...
#
#          assessed_by contacted admitted  helpful num_attempts  \
# 0    [ Tressie Kidd]      [NA]     [NA]     [NA]         [NA]
# 1   [ Angel Douglas]   [ Yes ]     [NA]  [ Yes ]         [NA]
# 2  [ Joshua Douglas]      [NA]     [NA]     [NA]         [NA]
# 3     [ Amanda Wood]   [ Yes ]     [NA]  [ Yes ]         [NA]
# 4     [ Amanda Wood]   [ Yes ]     [NA]  [ Yes ]         [NA]
#
#                   create                                referral voluntary  \
# 0  [ 4/1/2020 8:37:22AM]                                    [NA]      [NA]
# 1  [ 4/3/2020 3:16:01PM]                                    [NA]      [NA]
# 2  [ 4/3/2020 9:11:36PM]                                    [NA]      [NA]
# 3  [ 4/4/2020 1:32:15PM]  [Lakeside Behavioral Health Center - ]      [NA]
# 4  [ 4/4/2020 1:35:17PM]                                    [NA]      [NA]
#
#   telehealth first hospitalization
# 0       [NA]                    NA
# 1       [NA]                    NA
# 2       [NA]                    NA
# 3    [? No ]                  ? No
# 4       [NA]                    NA
#
# [5 rows x 57 columns]

# %%
df.to_csv('D:/data/results_df_2020_04.csv')
